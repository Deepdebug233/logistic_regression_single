# %%
import pandas as pd

df=pd.read_csv("/content/HR_comma_sep.csv")

# %%
df.head(60)
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.38             0.53               2                   157
# 1                 0.80             0.86               5                   262
# 2                 0.11             0.88               7                   272
# 3                 0.72             0.87               5                   223
# 4                 0.37             0.52               2                   159
# 5                 0.41             0.50               2                   153
# 6                 0.10             0.77               6                   247
# 7                 0.92             0.85               5                   259
# 8                 0.89             1.00               5                   224
# 9                 0.42             0.53               2                   142
# 10                0.45             0.54               2                   135
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1_7Soc_9Rlm-LZNfdp36aWRgZIStd6llqyZnJI_S5QXc#gid=0
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py:31: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return frame.applymap(_clean_val).replace({np.nan: None})
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1_7Soc_9Rlm-LZNfdp36aWRgZIStd6llqyZnJI_S5QXc#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import matplotlib.pyplot as plt

plt.scatter(df.left,df.time_spend_company ,marker='+')

# %%
plt.bar(df.Department,df.left,width=0.9)
# Out:
# <BarContainer object of 14999 artists>

# %%
plt.bar(df.left,df.salary)
# Out:
# <BarContainer object of 14999 artists>

# %%
# !pip install -U scikit-learn

# %%
from sklearn .model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df[['time_spend_company']],df.left,test_size=0.7)

# %%
X_train.head()
# Out:
#        time_spend_company
# 13454                   3
# 12812                   2
# 9957                    6
# 2019                    3
# 944                     4

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.7470549010891309

# %%
model.predict()
# Out:
# array([0, 0, 0, ..., 0, 0, 0])
